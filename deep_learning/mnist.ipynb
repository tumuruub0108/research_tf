# %%
from tensorflow.keras.datasets import mnist
from tensorflow import keras 
from tensorflow.keras import layers

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
print("train_images.shape=", train_images.shape)
print("train_labels", train_labels)
# Out:
# train_images.shape= (60000, 28, 28)
# train_labels [5 0 4 ... 5 6 8]

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
                loss="sparse_categorical_crossentropy",
                metrics=["accuracy"])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9230 - loss: 0.2658
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9679 - loss: 0.1072
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9789 - loss: 0.0699
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9851 - loss: 0.0514
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9885 - loss: 0.0383

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
print(predictions[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [1.00697925e-07 6.79645229e-09 2.57034517e-05 6.29479764e-05
#  8.04488531e-10 2.26451760e-07 1.14649935e-12 9.99901414e-01
#  4.40637820e-07 9.20809180e-06]

# %%
predictions[0].argmax()
# Out:
# np.int64(7)

# %%
predictions[0][7]
# Out:
# np.float32(0.9999014)

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9774 - loss: 0.0722

# %%
print(f"test_acc: {test_acc}")
# Out:
# test_acc: 0.977400004863739
